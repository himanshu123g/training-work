# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df.drop(columns="Cabin",inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
print(df.Fare.mean())
print(df.Fare.mode())
print(df.Fare.median())
print(df.Fare.min())
print(df.Fare.max())
# Out:
# 35.627188489208635
# 0    7.75
# Name: Fare, dtype: float64
# 14.4542
# 0.0
# 512.3292

# %%
df[df.Fare.isna()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Embarked
# 152      0   3701   NaN        S

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df[df["Pclass"]==3]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
print(df[df["Pclass"]==3].Fare.min())
print(df[df["Pclass"]==3].Fare.max())
# Out:
# 3.1708
# 69.55

# %%
print(df[df["Pclass"]==3].Fare.mean())
# Out:
# 12.459677880184334

# %%
df.Fare.fillna(df[df["Pclass"]==3].Fare.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12612\622776480.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Fare.fillna(df[df["Pclass"]==3].Fare.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# dtype: int64

# %%
df.Age.describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.Name.str.split(",")
# Out:
# 0                                  [Kelly,  Mr. James]
# 1                  [Wilkes,  Mrs. James (Ellen Needs)]
# 2                         [Myles,  Mr. Thomas Francis]
# 3                                  [Wirz,  Mr. Albert]
# 4      [Hirvonen,  Mrs. Alexander (Helga E Lindqvist)]
#                             ...
# 413                              [Spector,  Mr. Woolf]
# 414                    [Oliva y Ocana,  Dona. Fermina]
# 415                    [Saether,  Mr. Simon Sivertsen]
# 416                             [Ware,  Mr. Frederick]
# 417                        [Peter,  Master. Michael J]
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.split(",").str[1].str.strip()
# Out:
# 0                               Mr. James
# 1                Mrs. James (Ellen Needs)
# 2                      Mr. Thomas Francis
# 3                              Mr. Albert
# 4      Mrs. Alexander (Helga E Lindqvist)
#                       ...
# 413                             Mr. Woolf
# 414                         Dona. Fermina
# 415                   Mr. Simon Sivertsen
# 416                         Mr. Frederick
# 417                     Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df["New_Name"]=df["Name"].str.split(",").str[1].str.strip()

# %%
df.New_Name
# Out:
# 0                               Mr. James
# 1                Mrs. James (Ellen Needs)
# 2                      Mr. Thomas Francis
# 3                              Mr. Albert
# 4      Mrs. Alexander (Helga E Lindqvist)
#                       ...
# 413                             Mr. Woolf
# 414                         Dona. Fermina
# 415                   Mr. Simon Sivertsen
# 416                         Mr. Frederick
# 417                     Master. Michael J
# Name: New_Name, Length: 418, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
mr=df[df.New_Name.str.startswith("Mr.")]

# %%
mr
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 406         1298         0       2     Ware, Mr. William Jeffery  male  23.0
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
#
# ...

# %%
mr.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            57
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# New_Name        0
# dtype: int64

# %%
mr.Age.describe()
# Out:
# count    183.000000
# mean      32.000000
# std       11.804497
# min       14.000000
# 25%       23.000000
# 50%       28.500000
# 75%       40.000000
# max       67.000000
# Name: Age, dtype: float64

# %%
mr.fillna(mr.Age.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12612\4127061058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mr.fillna(mr.Age.mean(),inplace=True)

# %%
mrs=df[df.New_Name.str.startswith("Mrs.")]
mrs.Age.mean()
# Out:
# np.float64(38.903225806451616)

# %%
mrs
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 8            900         1       3
# 12           904         1       1
# 14           906         1       1
# ..           ...       ...     ...
# 383         1275         1       3
# 391         1283         1       1
# 395         1287         1       1
# 397         1289         1       1
# 411         1303         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
mrs.fillna(mrs.Age.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12612\2292488976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrs.fillna(mrs.Age.mean(),inplace=True)

# %%
miss=df[df.New_Name.str.startswith("Miss")]
miss.Age.mean()
# Out:
# np.float64(21.774843750000002)

# %%
miss.fillna(miss.Age.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12612\2987497817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   miss.fillna(miss.Age.mean(),inplace=True)

# %%
miss
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 6            898         1       3             Connolly, Miss. Kate  female
# 18           910         1       3     Ilmakangas, Miss. Ida Livija  female
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 36           928         1       3              Roth, Miss. Sarah A  female
# 37           929         1       3               Cacic, Miss. Manda  female
# ..           ...       ...     ...                              ...     ...
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
# 408         1300         1       3  Riordan, Miss. Johanna Hannah""  female
# 409         1301         1       3        Peacock, Miss. Treasteall  female
# 410         1302         1       3           Naughton, Miss. Hannah  female
# 412         1304         1       3   Henriksson, Miss. Jenny Lovisa  female
#
# ...

# %%
master=df[df.New_Name.str.startswith("Master")]

# %%
master.Age.mean()
# Out:
# np.float64(7.406470588235294)

# %%
master
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 21           913         0       3                  Olsen, Master. Artur Karl
# 55           947         0       3                       Rice, Master. Albert
# 64           956         0       1                Ryerson, Master. John Borie
# 80           972         0       3                       Boulos, Master. Akar
# 89           981         0       2                Wells, Master. Ralph Lester
# 154         1046         0       3               Asplund, Master. Filip Oscar
# 161         1053         0       3             Touma, Master. Georges Youssef
# 192         1084         0       3          van Billiard, Master. Walter John
# 194         1086         0       2              Drew, Master. Marshall Brines
# 196         1088         0       1            Spedden, Master. Robert Douglas
# 201         1093         0       3    Danbom, Master. Gilbert Sigvard Emanuel
# ...

# %%
master.fillna(master.Age.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_12612\3445227287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master.fillna(master.Age.mean(),inplace=True)

# %%
master
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 21           913         0       3                  Olsen, Master. Artur Karl
# 55           947         0       3                       Rice, Master. Albert
# 64           956         0       1                Ryerson, Master. John Borie
# 80           972         0       3                       Boulos, Master. Akar
# 89           981         0       2                Wells, Master. Ralph Lester
# 154         1046         0       3               Asplund, Master. Filip Oscar
# 161         1053         0       3             Touma, Master. Georges Youssef
# 192         1084         0       3          van Billiard, Master. Walter John
# 194         1086         0       2              Drew, Master. Marshall Brines
# 196         1088         0       1            Spedden, Master. Robert Douglas
# 201         1093         0       3    Danbom, Master. Gilbert Sigvard Emanuel
# ...

# %%
df1=pd.concat([mr,mrs,master,miss])

# %%
df1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# New_Name       0
# dtype: int64

# %%
# 29 jan tasks

# %%
#first question
cities=pd.DataFrame({"Jalandhar":[20,31,34,18,20,50], "chandigarh":[20,30,40,50,60, None]})

# %%
cities
# Out:
#    Jalandhar  chandigarh
# 0         20        20.0
# 1         31        30.0
# 2         34        40.0
# 3         18        50.0
# 4         20        60.0
# 5         50         NaN

# %%
cities.Jalandhar.mean()
# Out:
# np.float64(28.833333333333332)

# %%
cities.chandigarh.mean()
# Out:
# np.float64(40.0)

# %%
#second question
country_data=pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie', 'David', "Alex"], 'Age': [20,25, 30, 35, 40], 'City': ['New York', 'Los Angeles', 'Chicago', 'New York', "Lasvegus}"]})

# %%
country_data
# Out:
#       Name  Age         City
# 0    Alice   20     New York
# 1      Bob   25  Los Angeles
# 2  Charlie   30      Chicago
# 3    David   35     New York
# 4     Alex   40    Lasvegus}

# %%
country_data[(country_data.Age>25) & ((country_data.City=="New York") | (country_data.City=="New York"))]
# Out:
#     Name  Age      City
# 3  David   35  New York

# %%
# third question
countries=pd.Series(['alice@o7services.com', 'bob@gmail.com', 'charlie@yahoo.com'])

# %%
countries
# Out:
# 0    alice@o7services.com
# 1           bob@gmail.com
# 2       charlie@yahoo.com
# dtype: object

# %%
countries.str.split("@").str[1]
# Out:
# 0    o7services.com
# 1         gmail.com
# 2         yahoo.com
# dtype: object

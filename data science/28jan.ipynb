# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({"Name":["Baljit","Radhika","Rahul","Nitin","Taran"],"Age":[22,21,22,np.nan,22],"Gender":["male","female","male","male","female"],"City":"Jalandhar"},index=[1,2,3,4,5])
df
# Out:
#       Name   Age  Gender       City
# 1   Baljit  22.0    male  Jalandhar
# 2  Radhika  21.0  female  Jalandhar
# 3    Rahul  22.0    male  Jalandhar
# 4    Nitin   NaN    male  Jalandhar
# 5    Taran  22.0  female  Jalandhar

# %%
df["college"]=["IIT","Cambridge","MIT","IIM","IIT"]
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  Jalandhar        IIT
# 2  Radhika  21.0  female  Jalandhar  Cambridge
# 3    Rahul  22.0    male  Jalandhar        MIT
# 4    Nitin   NaN    male  Jalandhar        IIM
# 5    Taran  22.0  female  Jalandhar        IIT

# %%
df["City"]=["jalandhar","jaipur","Amritsar","Delhi","Jalandhar"]
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   Amritsar        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT

# %%
df.loc["f",:]=["Ram",20,"male","Jalandhar","Oxford"]
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   Amritsar        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT
# f      Ram  20.0    male  Jalandhar     Oxford

# %%
df.loc[3,"City"]="New york"
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT
# f      Ram  20.0    male  Jalandhar     Oxford

# %%
df.drop("f")
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT

# %%
df.drop("f")
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT

# %%
df.drop(columns=["college"])
# Out:
#       Name   Age  Gender       City
# 1   Baljit  22.0    male  jalandhar
# 2  Radhika  21.0  female     jaipur
# 3    Rahul  22.0    male   New york
# 4    Nitin   NaN    male      Delhi
# 5    Taran  22.0  female  Jalandhar
# f      Ram  20.0    male  Jalandhar

# %%
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT
# f      Ram  20.0    male  Jalandhar     Oxford

# %%
df.loc[6,:]=["hello",20,None,None,None]

# %%
df
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 4    Nitin   NaN    male      Delhi        IIM
# 5    Taran  22.0  female  Jalandhar        IIT
# f      Ram  20.0    male  Jalandhar     Oxford
# 6    hello  20.0    None       None       None

# %%
df.dropna()
# Out:
#       Name   Age  Gender       City    college
# 1   Baljit  22.0    male  jalandhar        IIT
# 2  Radhika  21.0  female     jaipur  Cambridge
# 3    Rahul  22.0    male   New york        MIT
# 5    Taran  22.0  female  Jalandhar        IIT
# f      Ram  20.0    male  Jalandhar     Oxford

# %%
df.dropna(axis=1)
# Out:
#       Name
# 1   Baljit
# 2  Radhika
# 3    Rahul
# 4    Nitin
# 5    Taran
# f      Ram
# 6    hello

# %%
df["Age"].mean()
# Out:
# np.float64(21.166666666666668)

# %%
df.Age.mode()
# Out:
# 0    22.0
# Name: Age, dtype: float64

# %%
df.Age.median()
# Out:
# np.float64(21.5)

# %%
df.Age.fillna(df.Age.mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20688\1807494962.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df
# Out:
#       Name        Age  Gender       City    college
# 1   Baljit  22.000000    male  jalandhar        IIT
# 2  Radhika  21.000000  female     jaipur  Cambridge
# 3    Rahul  22.000000    male   New york        MIT
# 4    Nitin  21.166667    male      Delhi        IIM
# 5    Taran  22.000000  female  Jalandhar        IIT
# f      Ram  20.000000    male  Jalandhar     Oxford
# 6    hello  20.000000    None       None       None

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Name        Age  Gender       City    college
# 1   Baljit  22.000000    male  jalandhar        IIT
# 2  Radhika  21.000000  female     jaipur  Cambridge
# 3    Rahul  22.000000    male   New york        MIT
# 4    Nitin  21.166667    male      Delhi        IIM
# 5    Taran  22.000000  female  Jalandhar        IIT
# f      Ram  20.000000    male  Jalandhar     Oxford

# %%
df[(df.City=="Jalandhar") | (df.City=="jalandhar")]
# Out:
#      Name   Age  Gender       City college
# 1  Baljit  22.0    male  jalandhar     IIT
# 5   Taran  22.0  female  Jalandhar     IIT
# f     Ram  20.0    male  Jalandhar  Oxford

# %%
df[(df.City=="Jalandhar") | (df.City=="jalandhar")]["Age"].mean()
# Out:
# np.float64(21.333333333333332)

# %%
df[df.Gender=="male"]["Name"]
# Out:
# 1    Baljit
# 3     Rahul
# 4     Nitin
# f       Ram
# Name: Name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 1 to f
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     6 non-null      object
#  1   Age      6 non-null      float64
#  2   Gender   6 non-null      object
#  3   City     6 non-null      object
#  4   college  6 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 460.0+ bytes

# %%
df.Age.describe()
# Out:
# count     6.000000
# mean     21.361111
# std       0.805651
# min      20.000000
# 25%      21.041667
# 50%      21.583333
# 75%      22.000000
# max      22.000000
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#              Age
# count   6.000000
# mean   21.361111
# std     0.805651
# min    20.000000
# 25%    21.041667
# 50%    21.583333
# 75%    22.000000
# max    22.000000

# %%
df.City.dtype
# Out:
# dtype('O')

# %%
df.City.str.upper()
# Out:
# 1    JALANDHAR
# 2       JAIPUR
# 3     NEW YORK
# 4        DELHI
# 5    JALANDHAR
# f    JALANDHAR
# Name: City, dtype: object

# %%
df["City"]=df.City.str.upper()

# %%
df
# Out:
#       Name        Age  Gender       City    college
# 1   Baljit  22.000000    male  JALANDHAR        IIT
# 2  Radhika  21.000000  female     JAIPUR  Cambridge
# 3    Rahul  22.000000    male   NEW YORK        MIT
# 4    Nitin  21.166667    male      DELHI        IIM
# 5    Taran  22.000000  female  JALANDHAR        IIT
# f      Ram  20.000000    male  JALANDHAR     Oxford

# %%
df.City.unique()
# Out:
# array(['JALANDHAR', 'JAIPUR', 'NEW YORK', 'DELHI'], dtype=object)

# %%
df.City.value_counts().sum()
# Out:
# np.int64(6)

# %%
df
# Out:
#       Name        Age  Gender       City    college
# 1   Baljit  22.000000    male  JALANDHAR        IIT
# 2  Radhika  21.000000  female     JAIPUR  Cambridge
# 3    Rahul  22.000000    male   NEW YORK        MIT
# 4    Nitin  21.166667    male      DELHI        IIM
# 5    Taran  22.000000  female  JALANDHAR        IIT
# f      Ram  20.000000    male  JALANDHAR     Oxford

# %%
df.insert(2,"Country",["German","India","Australia","Canada","Italy","Moscow"])

# %%
df
# Out:
#       Name        Age    Country  Gender       City    college
# 1   Baljit  22.000000     German    male  JALANDHAR        IIT
# 2  Radhika  21.000000      India  female     JAIPUR  Cambridge
# 3    Rahul  22.000000  Australia    male   NEW YORK        MIT
# 4    Nitin  21.166667     Canada    male      DELHI        IIM
# 5    Taran  22.000000      Italy  female  JALANDHAR        IIT
# f      Ram  20.000000     Moscow    male  JALANDHAR     Oxford

# %%
df.insert(4,"Gender",[1,2,3,4,5,6],allow_duplicates=True)

# %%
df
# Out:
#       Name        Age    Country  Gender  Gender       City    college
# 1   Baljit  22.000000     German    male       1  JALANDHAR        IIT
# 2  Radhika  21.000000      India  female       2     JAIPUR  Cambridge
# 3    Rahul  22.000000  Australia    male       3   NEW YORK        MIT
# 4    Nitin  21.166667     Canada    male       4      DELHI        IIM
# 5    Taran  22.000000      Italy  female       5  JALANDHAR        IIT
# f      Ram  20.000000     Moscow    male       6  JALANDHAR     Oxford

# %%
df.drop(columns="Gender")
# Out:
#       Name        Age    Country       City    college
# 1   Baljit  22.000000     German  JALANDHAR        IIT
# 2  Radhika  21.000000      India     JAIPUR  Cambridge
# 3    Rahul  22.000000  Australia   NEW YORK        MIT
# 4    Nitin  21.166667     Canada      DELHI        IIM
# 5    Taran  22.000000      Italy  JALANDHAR        IIT
# f      Ram  20.000000     Moscow  JALANDHAR     Oxford

# %%
df.rename(columns={"college":"College"},inplace=True)

# %%
df
# Out:
#       Name        Age    Country  Gender  Gender       City    College
# 1   Baljit  22.000000     German    male       1  JALANDHAR        IIT
# 2  Radhika  21.000000      India  female       2     JAIPUR  Cambridge
# 3    Rahul  22.000000  Australia    male       3   NEW YORK        MIT
# 4    Nitin  21.166667     Canada    male       4      DELHI        IIM
# 5    Taran  22.000000      Italy  female       5  JALANDHAR        IIT
# f      Ram  20.000000     Moscow    male       6  JALANDHAR     Oxford

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       Name        Age    Country  Gender  Gender       City    College
# 0   Baljit  22.000000     German    male       1  JALANDHAR        IIT
# 1  Radhika  21.000000      India  female       2     JAIPUR  Cambridge
# 2    Rahul  22.000000  Australia    male       3   NEW YORK        MIT
# 3    Nitin  21.166667     Canada    male       4      DELHI        IIM
# 4    Taran  22.000000      Italy  female       5  JALANDHAR        IIT
# 5      Ram  20.000000     Moscow    male       6  JALANDHAR     Oxford

# %%
df.reindex(index=[0,1,2,3,4,5])
# Out:
#       Name        Age    Country  Gender  Gender       City    College
# 0   Baljit  22.000000     German    male       1  JALANDHAR        IIT
# 1  Radhika  21.000000      India  female       2     JAIPUR  Cambridge
# 2    Rahul  22.000000  Australia    male       3   NEW YORK        MIT
# 3    Nitin  21.166667     Canada    male       4      DELHI        IIM
# 4    Taran  22.000000      Italy  female       5  JALANDHAR        IIT
# 5      Ram  20.000000     Moscow    male       6  JALANDHAR     Oxford

# %%
df.Age.apply(lambda x:x+5)
# Out:
# 0    27.000000
# 1    26.000000
# 2    27.000000
# 3    26.166667
# 4    27.000000
# 5    25.000000
# Name: Age, dtype: float64

# %%
import pandas as pd

# %%
ser=pd.Series([10,20,30,40,None,"sassy",None])
ser
# Out:
# 0       10
# 1       20
# 2       30
# 3       40
# 4     None
# 5    sassy
# 6     None
# dtype: object

# %%
ser.drop(3)
# Out:
# 0       10
# 1       20
# 2       30
# 4     None
# 5    sassy
# 6     None
# dtype: object

# %%
ser
# Out:
# 0       10
# 1       20
# 2       30
# 3       40
# 4     None
# 5    sassy
# 6     None
# dtype: object

# %%
ser.drop(3,inplace=True)

# %%
ser
# Out:
# 0       10
# 1       20
# 2       30
# 4     None
# 5    sassy
# 6     None
# dtype: object

# %%
ser.reset_index(drop=True,inplace=True)

# %%
ser
# Out:
# 0       10
# 1       20
# 2       30
# 3     None
# 4    sassy
# 5     None
# dtype: object

# %%
ser.isna()   #tells true if the value is none.
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
ser[ser.isna()]
# Out:
# 3    None
# 5    None
# dtype: object

# %%
ser.isna().sum()
# Out:
# np.int64(2)

# %%
ser.dropna(inplace=True)
ser
# Out:
# 0       10
# 1       20
# 2       30
# 4    sassy
# dtype: object

# %%
ser.reset_index(drop=True, inplace=True)

# %%
ser
# Out:
# 0       10
# 1       20
# 2       30
# 3    sassy
# dtype: object

# %%
# new series

# %%
ser1=pd.Series([10,20,30,40,None,None])
ser1
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
ser1.fillna(0)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4     0.0
# 5     0.0
# dtype: float64

# %%
ser1
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
ser1.mean()
# Out:
# np.float64(25.0)

# %%
ser1.median()
# Out:
# np.float64(25.0)

# %%
ser1.mode()
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
ser1.fillna(ser1.mean(),inplace=True)

# %%
ser1
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    25.0
# 5    25.0
# dtype: float64

# %%
ser1.sort_values()
# Out:
# 0    10.0
# 1    20.0
# 5    25.0
# 4    25.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
import numpy as np

# %%
arr=np.array([2,4,2,7,8])
arr
# Out:
# array([2, 4, 2, 7, 8])

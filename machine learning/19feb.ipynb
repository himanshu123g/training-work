# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("AUDIO.csv")
df.head()
# Out:
#   ticker        date    open    high     low   close
# 0  AUDIO  2021-01-08  0.1806  0.1920  0.1766  0.1917
# 1  AUDIO  2021-01-09  0.1917  0.1951  0.1744  0.1833
# 2  AUDIO  2021-01-10  0.1833  0.2095  0.1822  0.1931
# 3  AUDIO  2021-01-11  0.1931  0.1954  0.1612  0.1681
# 4  AUDIO  2021-01-12  0.1681  0.1812  0.1660  0.1694

# %%
df.drop(columns=["ticker",'date'],inplace=True)

# %%
df.head()
# Out:
#      open    high     low   close
# 0  0.1806  0.1920  0.1766  0.1917
# 1  0.1917  0.1951  0.1744  0.1833
# 2  0.1833  0.2095  0.1822  0.1931
# 3  0.1931  0.1954  0.1612  0.1681
# 4  0.1681  0.1812  0.1660  0.1694

# %%
sns.scatterplot(data=df,x="open",y="close")
# Out:
# <Axes: xlabel='open', ylabel='close'>

# %%
sns.scatterplot(data=df,x="high",y="close")
# Out:
# <Axes: xlabel='high', ylabel='close'>

# %%
sns.scatterplot(data=df,x="low",y="close")
# Out:
# <Axes: xlabel='low', ylabel='close'>

# %%
x=df.drop(columns="close") #as it is not an independent column
y=df["close"]

# %%
x
# Out:
#          open      high       low
# 0    0.180600  0.192000  0.176600
# 1    0.191700  0.195100  0.174400
# 2    0.183300  0.209500  0.182200
# 3    0.193100  0.195400  0.161200
# 4    0.168100  0.181200  0.166000
# ..        ...       ...       ...
# 923  0.184802  0.186698  0.183624
# 924  0.185819  0.188294  0.179523
# 925  0.185696  0.186798  0.175984
# 926  0.179778  0.181280  0.177189
# 927  0.178584  0.182600  0.174569
#
# [928 rows x 3 columns]

# %%
y
# Out:
# 0      0.191700
# 1      0.183300
# 2      0.193100
# 3      0.168100
# 4      0.169400
#          ...
# 923    0.185620
# 924    0.185698
# 925    0.179580
# 926    0.178288
# 927    0.180805
# Name: close, Length: 928, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#          open      high       low
# 873  0.236766  0.241570  0.234249
# 76   2.054000  2.550000  1.850000
# 487  0.621876  0.700860  0.566773
# 690  0.161105  0.161802  0.156411
# 473  1.147230  1.216240  1.033100
# ..        ...       ...       ...
# 833  0.299227  0.317067  0.291964
# 547  0.342394  0.342794  0.321111
# 657  0.195637  0.206578  0.195137
# 432  0.713214  0.743223  0.699210
# 437  1.066530  1.179590  0.993397
#
# [742 rows x 3 columns]

# %%
y_train
# Out:
# 873    0.240663
# 76     2.380000
# 487    0.580768
# 690    0.158309
# 473    1.056110
#          ...
# 833    0.298215
# 547    0.323309
# 657    0.201348
# 432    0.734220
# 437    1.002500
# Name: close, Length: 742, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
model=lr.fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.72482381, 0.18412974, 0.24455981, 0.82003477, 0.26742576,
#        0.28001924, 1.07186304, 0.35797633, 1.88136223, 0.29917268,
#        2.08691843, 1.09150344, 0.8226995 , 0.27109264, 0.18688125,
#        1.66814743, 0.21798237, 2.39170021, 1.15482568, 0.3516886 ,
#        0.25691024, 0.37683419, 0.34797164, 0.20266248, 2.06732452,
#        0.27948835, 1.57151476, 1.10445843, 2.2379739 , 0.20541409,
#        3.25507186, 0.16303136, 0.27751163, 0.35122434, 0.39106765,
#        1.154979  , 0.34829122, 2.26108382, 0.79216218, 0.27849233,
#        0.30126435, 0.32157067, 0.15388284, 0.48788901, 0.17393127,
#        1.5046854 , 3.90525742, 1.27351386, 1.02393802, 0.8310363 ,
#        0.15228891, 1.50118855, 2.07778873, 0.91839507, 1.7761044 ,
#        0.31076422, 0.28374933, 2.44009016, 0.29958009, 1.32458799,
#        1.20046344, 0.1917146 , 0.4242527 , 1.40302524, 0.73211841,
#        0.30639505, 0.17317995, 0.24969949, 1.60634396, 3.11412475,
# ...

# %%
y_test
# Out:
# 167    0.729500
# 912    0.179004
# 849    0.238738
# 135    0.915700
# 760    0.253825
#          ...
# 553    0.364105
# 480    0.826917
# 582    0.371689
# 913    0.177788
# 266    2.355000
# Name: close, Length: 186, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9980013053551476

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Superstore Dataset.csv")

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2019-103800  03-01-2019  07-01-2019  Standard Class    DP-13000
# 1  CA-2019-112326  04-01-2019  08-01-2019  Standard Class    PO-19195
# 2  CA-2019-112326  04-01-2019  08-01-2019  Standard Class    PO-19195
# 3  CA-2019-112326  04-01-2019  08-01-2019  Standard Class    PO-19195
# 4  CA-2019-141817  05-01-2019  12-01-2019  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City         State  \
# 0  Darren Powers     Consumer  United States       Houston         Texas
# 1  Phillina Ober  Home Office  United States    Naperville      Illinois
# 2  Phillina Ober  Home Office  United States    Naperville      Illinois
# 3  Phillina Ober  Home Office  United States    Naperville      Illinois
# 4     Mick Brown     Consumer  United States  Philadelphia  Pennsylvania
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df.shape
# Out:
# (9994, 20)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y')

# %%
df.shape
# Out:
# (9993, 20)

# %%
df.Region.unique()
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
df.Sales.unique()
# Out:
# array([ 16.448,  11.784, 272.736, ...,   3.024,  52.776,  90.93 ],
#       shape=(5825,))

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Central    501239.8908
# East       678499.8680
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Profit"].sum()
# Out:
# Region
# Central     39706.3625
# East        91534.8388
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
df.head()
# Out:
#          Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2019-103800 2019-01-03  07-01-2019  Standard Class    DP-13000
# 1  CA-2019-112326 2019-01-04  08-01-2019  Standard Class    PO-19195
# 2  CA-2019-112326 2019-01-04  08-01-2019  Standard Class    PO-19195
# 3  CA-2019-112326 2019-01-04  08-01-2019  Standard Class    PO-19195
# 4  CA-2019-141817 2019-01-05  12-01-2019  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City         State  \
# 0  Darren Powers     Consumer  United States       Houston         Texas
# 1  Phillina Ober  Home Office  United States    Naperville      Illinois
# 2  Phillina Ober  Home Office  United States    Naperville      Illinois
# 3  Phillina Ober  Home Office  United States    Naperville      Illinois
# 4     Mick Brown     Consumer  United States  Philadelphia  Pennsylvania
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
df["Sub-Category"].unique()
# Out:
# array(['Paper', 'Labels', 'Storage', 'Binders', 'Art', 'Chairs', 'Phones',
#        'Fasteners', 'Furnishings', 'Accessories', 'Envelopes',
#        'Bookcases', 'Appliances', 'Tables', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Sub-Category
# Phones     330007.054
# Chairs     328167.731
# Storage    223843.608
# Tables     206965.532
# Binders    203412.733
# Name: Sales, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   datetime64[ns]
#  2   Ship Date      9993 non-null   object
#  3   Ship Mode      9993 non-null   object
#  4   Customer ID    9993 non-null   object
#  5   Customer Name  9993 non-null   object
#  6   Segment        9993 non-null   object
#  7   Country        9993 non-null   object
#  8   City           9993 non-null   object
#  9   State          9993 non-null   object
#  10  Postal Code    9993 non-null   int64
#  11  Region         9993 non-null   object
#  12  Product ID     9993 non-null   object
#  13  Category       9993 non-null   object
#  14  Sub-Category   9993 non-null   object
#  15  Product Name   9993 non-null   object
#  16  Sales          9993 non-null   float64
# ...

# %%
orders_after_2021 = df[df['Order Date'] > '2021-01-01']

# %%
orders_after_2021
# Out:
#             Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 4097  CA-2021-105207 2021-01-02  07-01-2021  Standard Class    BO-11350
# 4098  US-2021-116365 2021-01-02  07-01-2021  Standard Class    CA-12310
# 4099  CA-2021-125206 2021-01-02  04-01-2021     First Class    LR-16915
# 4100  US-2021-116365 2021-01-02  07-01-2021  Standard Class    CA-12310
# 4101  CA-2021-105207 2021-01-02  07-01-2021  Standard Class    BO-11350
# ...              ...        ...         ...             ...         ...
# 9989  CA-2022-156720 2022-12-30  03-01-2023  Standard Class    JM-15580
# 9990  CA-2022-143259 2022-12-30  03-01-2023  Standard Class    PO-18865
# 9991  CA-2022-143259 2022-12-30  03-01-2023  Standard Class    PO-18865
# 9992  CA-2022-115427 2022-12-30  03-01-2023  Standard Class    EB-13975
# 9993  CA-2022-143259 2022-12-30  03-01-2023  Standard Class    PO-18865
#
#           Customer Name    Segment        Country           City       State  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %%
df["ratio"]=df["Profit"]/df["Sales"]

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'ratio'],
#       dtype='object')

# %%
df.groupby("Order ID")["ratio"].sum().sort_values(ascending=False).head(5)
# Out:
# Order ID
# CA-2022-100111    4.131944
# CA-2020-132626    3.490000
# US-2021-108504    3.100000
# CA-2022-157987    3.077500
# CA-2019-142769    3.060000
# Name: ratio, dtype: float64
